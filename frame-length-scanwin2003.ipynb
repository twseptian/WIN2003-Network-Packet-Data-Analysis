# %%
# !tshark -n -r scan_win2003_tcpdump.pcap -T fields -Eheader=y -e frame.number -e frame.len > frame.len

# %%
import pandas as pd

# %%
df=pd.read_table("frame.len")
df.head()
# Out:
#    frame.number  frame.len
# 0             1         66
# 1             2         60
# 2             3         60
# 3             4         60
# 4             5         60

# %%
df["frame.len"].describe()
# Out:
# count    677914.000000
# mean        294.668173
# std         479.635173
# min          42.000000
# 25%          60.000000
# 50%          62.000000
# 75%         246.000000
# max        1514.000000
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df["frame.len"].plot(style=".", alpha=0.2,figsize=(10,6))
title("Frame length Redhat-Passguessing")
ylabel("bytes")
xlabel("frame number")
